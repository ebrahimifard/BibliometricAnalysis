# %% [markdown]
# # Growth

# %%
import pickle as pk
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import *
import random
import seaborn as sns

# %%
sns.set()

# %%
adr = "./SerializedData/"

# %%
papers = pk.loads(open(adr+"RumourPapers.pickle","rb").read())

# %%
pub_year = papers.groupby("PY").count()["PT"]
pub_year = pd.to_numeric(pub_year)

# %%
x = pd.to_numeric(pub_year.to_frame().reset_index()["PY"])
y = pub_year.to_frame().reset_index()["PT"]

# %%
sns_plot = sns.regplot(x, y, marker="+", color="b", truncate=False, x_jitter=.1, order=1)
plt.ylabel("Publications count")
fig = sns_plot.get_figure()
